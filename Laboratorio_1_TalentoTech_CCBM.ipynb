# %% [markdown]
# <a href="https://colab.research.google.com/github/ccbeltran/Talento_Tech/blob/main/Laboratorio_1_TalentoTech_CCBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar librerías a utilizar
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importar el archivo desde la ruta personal de Google Drive
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive')  # Establecemos la conexión através del método mount
# Out:
# Mounted at /content/drive

# %%
#Establezco la conexión con mi fuente y con el dataset de prueba Dataset1.csv
ruta = '/content/drive/MyDrive/TalentoTech/Python/dataset_banco.csv'

# %%
# Definimos la variable
ruta = "/content/drive/MyDrive/TalentoTech/Python/dataset_banco.csv"
data = pd.read_csv(ruta)

# %%
# Realizamos lectura del archivo
data.head()
print(data)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no   2143.0     yes   no
# 1       44    technician    single  secondary      no     29.0     yes   no
# 2       33  entrepreneur   married  secondary      no      2.0     yes  yes
# 3       47   blue-collar   married    unknown      no   1506.0     yes   no
# 4       33       unknown    single    unknown      no      1.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may     261.0         1   -1.0         0  unknown   no
# 1        unknown    5   may     151.0         1   -1.0         0  unknown   no
# 2        unknown    5   may      76.0         1   -1.0         0  unknown   no
# 3        unknown    5   may      92.0         1   -1.0         0  unknown   no
# 4        unknown    5   may     198.0         1   -1.0         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45210   cellular   17   nov     977.0         3   -1.0         0  unknown  yes
# 45211   cellular   17   nov     456.0         2   -1.0         0  unknown  yes
# 45212   cellular   17   nov    1127.0         5  184.0         3  success  yes
# 45213  telephone   17   nov     508.0         4   -1.0         0  unknown   no
# 45214   cellular   17   nov     361.0         2  188.0        11    other   no
#
# [45215 rows x 17 columns]

# %%
# Realizamos lectura del archivo
data.tail()
print(data)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no   2143.0     yes   no
# 1       44    technician    single  secondary      no     29.0     yes   no
# 2       33  entrepreneur   married  secondary      no      2.0     yes  yes
# 3       47   blue-collar   married    unknown      no   1506.0     yes   no
# 4       33       unknown    single    unknown      no      1.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may     261.0         1   -1.0         0  unknown   no
# 1        unknown    5   may     151.0         1   -1.0         0  unknown   no
# 2        unknown    5   may      76.0         1   -1.0         0  unknown   no
# 3        unknown    5   may      92.0         1   -1.0         0  unknown   no
# 4        unknown    5   may     198.0         1   -1.0         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45210   cellular   17   nov     977.0         3   -1.0         0  unknown  yes
# 45211   cellular   17   nov     456.0         2   -1.0         0  unknown  yes
# 45212   cellular   17   nov    1127.0         5  184.0         3  success  yes
# 45213  telephone   17   nov     508.0         4   -1.0         0  unknown   no
# 45214   cellular   17   nov     361.0         2  188.0        11    other   no
#
# [45215 rows x 17 columns]

# %%
data.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45210   cellular   17   nov     977.0         3   -1.0         0  unknown  yes
# 45211   cellular   17   nov     456.0         2   -1.0         0  unknown  yes
# 45212   cellular   17   nov    1127.0         5  184.0         3  success  yes
# 45213  telephone   17   nov     508.0         4   -1.0         0  unknown   no
# 45214   cellular   17   nov     361.0         2  188.0        11    other   no

# %%
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no   2143.0     yes   no
# 1   44    technician   single  secondary      no     29.0     yes   no
# 2   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3   47   blue-collar  married    unknown      no   1506.0     yes   no
# 4   33       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may     261.0         1   -1.0         0  unknown  no
# 1  unknown    5   may     151.0         1   -1.0         0  unknown  no
# 2  unknown    5   may      76.0         1   -1.0         0  unknown  no
# 3  unknown    5   may      92.0         1   -1.0         0  unknown  no
# 4  unknown    5   may     198.0         1   -1.0         0  unknown  no

# %%
data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45215.000000   45213.000000  45215.000000  45214.000000  45215.000000
# mean      41.004711    1374.159866     15.805839    258.074357      2.763729
# std       12.036647    3924.255525      8.322473    257.605175      3.097910
# min       18.000000   -8019.000000      1.000000  -1389.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max      776.000000  527532.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45214.000000  45215.000000
# mean      40.192485      0.580383
# std      100.120622      2.303438
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
data.query("education =='primary' and age > 200")
# Out:
#       age          job  marital education default  balance housing loan  \
# 1076  490     services   single   primary      no    114.0     yes   no
# 6053  399  blue-collar  married   primary      no   2805.0     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 1076  unknown    7   may      99.0         2   -1.0         0  unknown  no
# 6053  unknown   26   may     102.0        23   -1.0         0  unknown  no

# %%
print(data.shape)
# Out:
# (45215, 17)

# %%
data_rename_2 = data

# %%
df = data_rename_2

# %%
#cambia los nombres de las columnas del dataframe de Ingles a Español
# Renombramos las columnas
data_rename_2 = df.rename(columns={
                                  'age':        'edad',
                                  'job':        'trabajo',
                                  'marital':    'estado_civil',
                                  'education':  'educacion',
                                  'default':    'morosidad',
                                  'balance':    'saldo',
                                  'housing':    'vivienda',
                                  'loan':       'prestamo',
                                  'contact':    'contacto',
                                  'day':        'dia',
                                  'month':      'mes',
                                  'duration':   'duracion',
                                  'campaign':   'campana',
                                  'pdays':      'dias_previos',
                                  'previous':   'anterior',
                                  'poutcome':   'resultado',
                                  'y':          'respuesta'})

# Verificamos los cambios con el comando print
print(data_rename_2.head())
# Out:
#    edad       trabajo estado_civil  educacion morosidad   saldo vivienda  \
# 0    58    management      married   tertiary        no  2143.0      yes
# 1    44    technician       single  secondary        no    29.0      yes
# 2    33  entrepreneur      married  secondary        no     2.0      yes
# 3    47   blue-collar      married    unknown        no  1506.0      yes
# 4    33       unknown       single    unknown        no     1.0       no
#
#   prestamo contacto  dia  mes  duracion  campana  dias_previos  anterior  \
# 0       no  unknown    5  may     261.0        1          -1.0         0
# 1       no  unknown    5  may     151.0        1          -1.0         0
# 2      yes  unknown    5  may      76.0        1          -1.0         0
# 3       no  unknown    5  may      92.0        1          -1.0         0
# 4       no  unknown    5  may     198.0        1          -1.0         0
#
#   resultado respuesta
# 0   unknown        no
# 1   unknown        no
# 2   unknown        no
# 3   unknown        no
# 4   unknown        no

# %%
# Renombrar las columnas #2
df.columns = ['edad',
              'trabajo',
              'estado_civil',
              'educacion',
              'incumplimiento',
              'saldo',
              'vivienda',
              'prestamo',
              'contacto',
              'dia',
              'mes',
              'duracion',
              'campaña',
              'dias_previos',
              'anterior',
              'resultado_prev',
              'respuesta']

print(df.columns)
# Out:
# Index(['edad', 'trabajo', 'estado_civil', 'educacion', 'incumplimiento',
#        'saldo', 'vivienda', 'prestamo', 'contacto', 'dia', 'mes', 'duracion',
#        'campaña', 'dias_previos', 'anterior', 'resultado_prev', 'respuesta'],
#       dtype='object')

# %%
#visualiza las primeras líneas de tu .csv
df.head()
# Out:
#    edad       trabajo estado_civil  educacion incumplimiento   saldo vivienda  \
# 0    58    management      married   tertiary             no  2143.0      yes
# 1    44    technician       single  secondary             no    29.0      yes
# 2    33  entrepreneur      married  secondary             no     2.0      yes
# 3    47   blue-collar      married    unknown             no  1506.0      yes
# 4    33       unknown       single    unknown             no     1.0       no
#
#   prestamo contacto  dia  mes  duracion  campaña  dias_previos  anterior  \
# 0       no  unknown    5  may     261.0        1          -1.0         0
# 1       no  unknown    5  may     151.0        1          -1.0         0
# 2      yes  unknown    5  may      76.0        1          -1.0         0
# 3       no  unknown    5  may      92.0        1          -1.0         0
# 4       no  unknown    5  may     198.0        1          -1.0         0
#
#   resultado_prev respuesta
# 0        unknown        no
# 1        unknown        no
# 2        unknown        no
# 3        unknown        no
# 4        unknown        no

# %%
#visualiza las variables categóricas y las numéricas
# Clasificar columnas
categoricas = df.select_dtypes(include=['object']).columns.tolist()
numericas = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Columnas categóricas:", categoricas)
print("Columnas numéricas:", numericas)
# Out:
# Columnas categóricas: ['trabajo', 'estado_civil', 'educacion', 'incumplimiento', 'vivienda', 'prestamo', 'contacto', 'mes', 'resultado_prev', 'respuesta']
# Columnas numéricas: ['edad', 'saldo', 'dia', 'duracion', 'campaña', 'dias_previos', 'anterior']

# %%
pd.value_counts(df['job'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'job'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-1466f623d583> in <cell line: 1>()
# ----> 1 pd.value_counts(df['job'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'job'

# %%
#Comando para contar los valores faltantes de mi dataframe
data.isna().sum()
# Out:
# edad              0
# trabajo           2
# estado_civil      1
# educacion         1
# incumplimiento    0
# saldo             2
# vivienda          0
# prestamo          0
# contacto          0
# dia               0
# mes               0
# duracion          1
# campaña           0
# dias_previos      1
# anterior          0
# resultado_prev    0
# respuesta         0
# dtype: int64

# %%
#elimino los valores faltantes de mi dataframe
data.dropna(inplace=True)

#conteo de valores por columna de mi dataframe
data.count()
# Out:
# edad              45207
# trabajo           45207
# estado_civil      45207
# educacion         45207
# incumplimiento    45207
# saldo             45207
# vivienda          45207
# prestamo          45207
# contacto          45207
# dia               45207
# mes               45207
# duracion          45207
# campaña           45207
# dias_previos      45207
# anterior          45207
# resultado_prev    45207
# respuesta         45207
# dtype: int64

# %%
# Conteo de los niveles en las diferentes columnas categóricas
cols_cat = ['job', 'marital', 'education', 'default', 'housing',
       'loan', 'contact', 'month', 'poutcome', 'y']

for col in cols_cat:
  print(f'Columna {col}: {df[col].nunique()} subniveles')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'job'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-4923a5562b3a> in <cell line: 5>()
#       4
#       5 for col in cols_cat:
# ----> 6   print(f'Columna {col}: {df[col].nunique()} subniveles')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'job'

# %%
#Conteo los valores
pd.value_counts(df['job'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'job'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-9f43697691c7> in <cell line: 2>()
#       1 #Conteo los valores
# ----> 2 pd.value_counts(df['job'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'job'

# %%
# Calcular la desviación estándar para las columnas numéricas
desviaciones_estandar = data[['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']].std()

# Imprimir las desviaciones estándar
print(desviaciones_estandar)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-35786ac3c2e0> in <cell line: 2>()
#       1 # Calcular la desviación estándar para las columnas numéricas
# ----> 2 desviaciones_estandar = data[['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']].std()
#       3
#       4 # Imprimir las desviaciones estándar
#       5 print(desviaciones_estandar)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5936                 if use_interval_msg:
#    5937                     key = list(key)
# -> 5938                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')] are in the [columns]"

# %%
#desviacion estandar para la variable 'pdays'
destd_pdays = data[['pdays']].std()

# Imprimir las desviaciones estándar
print(destd_pdays)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-5329fee5a319> in <cell line: 2>()
#       1 #desviacion estandar para la variable 'pdays'
# ----> 2 destd_pdays = data[['pdays']].std()
#       3
#       4 # Imprimir las desviaciones estándar
#       5 print(destd_pdays)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5936                 if use_interval_msg:
#    5937                     key = list(key)
# -> 5938                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['pdays'], dtype='object')] are in the [columns]"

# %%
# Crear una gráfica de barras para representar las desviaciones estándar
desviaciones_estandar.plot(kind='bar')
plt.title('Desviación Estándar de las Variables Numéricas')
plt.xlabel('Variables')
plt.ylabel('Desviación Estándar')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-160a8ba6385c> in <cell line: 2>()
#       1 # Crear una gráfica de barras para representar las desviaciones estándar
# ----> 2 desviaciones_estandar.plot(kind='bar')
#       3 plt.title('Desviación Estándar de las Variables Numéricas')
#       4 plt.xlabel('Variables')
#       5 plt.ylabel('Desviación Estándar')
#
# NameError: name 'desviaciones_estandar' is not defined

# %%
# Graficar la desviación estándar de 'pdays'
plt.figure(figsize=(4, 2))  # Configura el tamaño de la figura
plt.bar('pdays', destd_pdays)  # Crea una barra para la desviación estándar de 'pdays'
plt.title('Desviación Estándar de pdays')
plt.ylabel('Desviación Estándar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-182f93081717> in <cell line: 3>()
#       1 # Graficar la desviación estándar de 'pdays'
#       2 plt.figure(figsize=(4, 2))  # Configura el tamaño de la figura
# ----> 3 plt.bar('pdays', destd_pdays)  # Crea una barra para la desviación estándar de 'pdays'
#       4 plt.title('Desviación Estándar de pdays')
#       5 plt.ylabel('Desviación Estándar')
#
# NameError: name 'destd_pdays' is not defined

# %%
# Calcula la media del atributo "pdays: dias de contacto al usuario antes de la campaña actual"
media = data['pdays'].mean()

print("Promedio de dias de contacto:", media)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pdays'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-cd4118a85cc6> in <cell line: 2>()
#       1 # Calcula la media del atributo "pdays: dias de contacto al usuario antes de la campaña actual"
# ----> 2 media = data['pdays'].mean()
#       3
#       4 print("Promedio de dias de contacto:", media)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'pdays'

# %%
# Graficar un histograma del atributo "pdays"
plt.hist(data['pdays'], bins=20, color='skyblue', edgecolor='black')

# Agregar una línea vertical para mostrar la media
plt.axvline(media, color='red', linestyle='dashed', linewidth=1)

# Etiquetas y título
plt.xlabel('Valor de la pdays')
plt.ylabel('Frecuencia')
plt.title('Histograma de la pdays con Media')

# Mostrar la gráfica
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pdays'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-0ceeb1ed6947> in <cell line: 2>()
#       1 # Graficar un histograma del atributo "pdays"
# ----> 2 plt.hist(data['pdays'], bins=20, color='skyblue', edgecolor='black')
#       3
#       4 # Agregar una línea vertical para mostrar la media
#       5 plt.axvline(media, color='red', linestyle='dashed', linewidth=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'pdays'
