# %% [markdown]
# <a href="https://colab.research.google.com/github/ccbeltran/Talento_Tech/blob/main/Laboratorio_1_TalentoTech_CCBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive') # Establecemos la conexión através del método mount
# Out:
# Mounted at /content/drive

# %%
#Establezco la conexión con mi fuente y con el dataset de prueba Ventas.xlsx
path = '/content/drive/MyDrive/Colab Notebooks/Bootcamp_TalentoTech/ventas.xlsx'

# %%
#importamos libreria para manipulacion llamada Pandas
import pandas as pd

# %%
#Creamos un dataframe de pandas con los datos suministrado
df_ventas = pd.read_excel(path)

# %%
df_ventas.columns
# Out:
# Index(['Fecha', 'Region', 'Producto', 'Vendedor', 'Ventas'], dtype='object')

# %%
# Muestra las primeras filas del DataFrame
df_ventas.tail()
# Out:
#         Fecha Region      Producto Vendedor  Ventas
# 13 2024-02-13  Oeste    Accesorios     Sara    5442
# 14 2024-02-14  Oeste  Dispositivos    Kevin   10711
# 15 2024-02-15  Oeste  Dispositivos     Sara    8780
# 16 2024-02-16  Oeste      Sistemas    Kevin   32855
# 17 2024-02-17  Oeste      Sistemas     Sara   23151

# %%
# Muestra las ultimas filas del Dataframe
df_ventas.head()
# Out:
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 1 2024-02-01  Central    Accesorios    Karen    6909
# 2 2024-02-02  Central  Dispositivos    David   11420
# 3 2024-02-03  Central  Dispositivos    Karen   12948
# 4 2024-02-04  Central      Sistemas    David   20098

# %%
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fecha     18 non-null     datetime64[ns]
#  1   Region    18 non-null     object
#  2   Producto  18 non-null     object
#  3   Vendedor  18 non-null     object
#  4   Ventas    18 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 848.0+ bytes

# %%
df_ventas.describe()
# Out:
#                      Fecha        Ventas
# count                   18     18.000000
# mean   2024-02-08 12:00:00  13307.388889
# min    2024-01-31 00:00:00   4744.000000
# 25%    2024-02-04 06:00:00   8410.250000
# 50%    2024-02-08 12:00:00  10529.500000
# 75%    2024-02-12 18:00:00  13491.750000
# max    2024-02-17 00:00:00  32855.000000
# std                    NaN   8153.055776
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Ventas'].plot(kind='hist', bins=20, title='Ventas')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ---------------------------------------------------------------------------
# ...

# %%
from matplotlib import pyplot as plt
_df_0['Ventas'].plot(kind='hist', bins=20, title='Ventas')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Ejercicio 1: Mostrar las primeras filas del DataFrame
print("Ejercicio 1: Mostrar las primeras filas del DataFrame")
print(df_ventas.head(5))
# Out:
# Ejercicio 1: Mostrar las primeras filas del DataFrame
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 1 2024-02-01  Central    Accesorios    Karen    6909
# 2 2024-02-02  Central  Dispositivos    David   11420
# 3 2024-02-03  Central  Dispositivos    Karen   12948
# 4 2024-02-04  Central      Sistemas    David   20098

# %%
#Ejercicio 2: Calcular el total de ventas por región
print("Ejercicio 2: Calcular el total de ventas por región")
ventas_por_region = df_ventas.groupby('Region')['Ventas'].sum()
print("\n")
print(df_ventas.head(10))
# Out:
# Ejercicio 2: Calcular el total de ventas por región
#
#
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 1 2024-02-01  Central    Accesorios    Karen    6909
# 2 2024-02-02  Central  Dispositivos    David   11420
# 3 2024-02-03  Central  Dispositivos    Karen   12948
# 4 2024-02-04  Central      Sistemas    David   20098
# 5 2024-02-05  Central      Sistemas    Karen   30633
# 6 2024-02-06     Este    Accesorios      Ana    9323
# 7 2024-02-07     Este    Accesorios    Lucas    7667
# 8 2024-02-08     Este  Dispositivos      Ana   10348
# 9 2024-02-09     Este  Dispositivos    Lucas    9312

# %%
#Ejercicio 2: Calcular el total de ventas por región
print("Ejercicio 2: Calcular el total de ventas por región")
ventas_por_region = df_ventas.groupby('Producto')['Ventas'].sum()
print(ventas_por_region)
# Out:
# Ejercicio 2: Calcular el total de ventas por región
# Producto
# Accesorios       42372
# Dispositivos     63519
# Sistemas        133642
# Name: Ventas, dtype: int64

# %%
#Ejercicio 3: Filtrar el DataFrame para mostrar solo las ventas realizadas por karen
print("Filtrar el DataFrame para mostrar solo las ventas realizadas por karen")
ventas_karen = df_ventas['Vendedor'] == 'Karen'
print(ventas_karen)
# Out:
# Filtrar el DataFrame para mostrar solo las ventas realizadas por karen
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# Name: Vendedor, dtype: bool

# %%
#Ejercicio 4: Calcular el promedio de ventas por region
print("Ejercicio 4: Calcular el promedio de ventas por region")
ventas_por_producto = df_ventas.groupby ('Region')['Ventas'].mean()
print(ventas_por_producto)
# Out:
# Ejercicio 4: Calcular el promedio de ventas por region
# Region
# Central    15049.166667
# Este       10592.500000
# Oeste      14280.500000
# Name: Ventas, dtype: float64

# %%
#prompt: Ejercicio 5: Calcular el promedio de ventas por region con dos decimales
print("Ejercicio 5: Calcular el promedio de ventas por region con dos decimale")
ventas_por_producto = df_ventas.groupby('Region')['Ventas'].mean().round(2)
print(ventas_por_producto)
# Out:
# Ejercicio 5: Calcular el promedio de ventas por region con dos decimale
# Region
# Central    15049.17
# Este       10592.50
# Oeste      14280.50
# Name: Ventas, dtype: float64

# %%
# Ejercio 6: Ordenar el DataFrame por ventas en orden descendente
print("Ejercio 6: Ordenar el DataFrame por ventas en orden descendente")
df_ordenado = df_ventas.sort_values(by='Ventas', ascending=False)
print(df_ordenado)
# Out:
# Ejercio 6: Ordenar el DataFrame por ventas en orden descendente
#         Fecha   Region      Producto Vendedor  Ventas
# 16 2024-02-16    Oeste      Sistemas    Kevin   32855
# 5  2024-02-05  Central      Sistemas    Karen   30633
# 17 2024-02-17    Oeste      Sistemas     Sara   23151
# 4  2024-02-04  Central      Sistemas    David   20098
# 10 2024-02-10     Este      Sistemas      Ana   13531
# 11 2024-02-11     Este      Sistemas    Lucas   13374
# 3  2024-02-03  Central  Dispositivos    Karen   12948
# 2  2024-02-02  Central  Dispositivos    David   11420
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 8  2024-02-08     Este  Dispositivos      Ana   10348
# 6  2024-02-06     Este    Accesorios      Ana    9323
# 9  2024-02-09     Este  Dispositivos    Lucas    9312
# 15 2024-02-15    Oeste  Dispositivos     Sara    8780
# 0  2024-01-31  Central    Accesorios    David    8287
# 7  2024-02-07     Este    Accesorios    Lucas    7667
# ...

# %%
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive/MyDrive/Colab Notebooks/Bootcamp_TalentoTech/Dataset1.csv') # Establecemos la conexión através del método mount
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-cb0948f8caba> in <cell line: 2>()
#       1 from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
# ----> 2 drive.mount('/content/drive/MyDrive/Colab Notebooks/Bootcamp_TalentoTech/Dataset1.csv') # Establecemos la conexión através del método mount
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
# ...

# %%
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive') # Establecemos la conexión através del método mount
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Establezco la conexión con mi fuente y con el dataset de prueba Dataset1.csv
file_path = '/content/drive/MyDrive/TalentoTech/Python/dataset_banco.csv'

# %%
#importamos libreria para manipulacion llamada Pandas
import pandas as pd

# %%
import matplotlib.pyplot as plt #Libreria que permite graficar

# %%
import seaborn as sns #Libreria que permite graficar

# %%
#Creamos un dataframe de pandas con los datos suministrado
df_bancos = pd.read_csv(file_path)

# %%
df_bancos.head()
print(df_bancos)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no   2143.0     yes   no
# 1       44    technician    single  secondary      no     29.0     yes   no
# 2       33  entrepreneur   married  secondary      no      2.0     yes  yes
# 3       47   blue-collar   married    unknown      no   1506.0     yes   no
# 4       33       unknown    single    unknown      no      1.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
# ...

# %%
df_bancos.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45210   cellular   17   nov     977.0         3   -1.0         0  unknown  yes
# 45211   cellular   17   nov     456.0         2   -1.0         0  unknown  yes
# 45212   cellular   17   nov    1127.0         5  184.0         3  success  yes
# 45213  telephone   17   nov     508.0         4   -1.0         0  unknown   no
# 45214   cellular   17   nov     361.0         2  188.0        11    other   no

# %%
df_bancos.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45215.000000   45213.000000  45215.000000  45214.000000  45215.000000
# mean      41.004711    1374.159866     15.805839    258.074357      2.763729
# std       12.036647    3924.255525      8.322473    257.605175      3.097910
# min       18.000000   -8019.000000      1.000000  -1389.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max      776.000000  527532.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45214.000000  45215.000000
# mean      40.192485      0.580383
# std      100.120622      2.303438
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df_bancos.query("education =='primary' and age > 200")
# Out:
#       age          job  marital education default  balance housing loan  \
# 1076  490     services   single   primary      no    114.0     yes   no
# 6053  399  blue-collar  married   primary      no   2805.0     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 1076  unknown    7   may      99.0         2   -1.0         0  unknown  no
# 6053  unknown   26   may     102.0        23   -1.0         0  unknown  no

# %%
print(df_bancos.shape)
# Out:
# (45215, 17)

# %%
#Renombrar columnas
data_rename = df_bancos(columns{
    'age':  'edad',
    'job':  'trabajo',
    'marital': 'estado_civil',
    'education': 'educacion',
    'default': 'morosidad',
    'balance':'saldo',
    'housing':'vivienda',
    'loan':'prestamo',
    'contact':'contacto',


})
