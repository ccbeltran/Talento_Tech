# %% [markdown]
# <a href="https://colab.research.google.com/github/ccbeltran/Talento_Tech/blob/main/Laboratorio_1_TalentoTech_CCBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar librerías a utilizar
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importar el archivo desde la ruta personal de Google Drive
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive')  # Establecemos la conexión através del método mount
# Out:
# Mounted at /content/drive

# %%
#Establezco la conexión con mi fuente y con el dataset de prueba Dataset1.csv
ruta = '/content/drive/MyDrive/TalentoTech/Python/dataset_banco.csv'

# %%
# Definimos la variable
ruta = "/content/drive/MyDrive/TalentoTech/Python/dataset_banco.csv"
data = pd.read_csv(ruta)

# %%
# Realizamos lectura del archivo
data.head()
print(data)
# Out:
#        edad       trabajo estado_civil  educacion incumplimiento   saldo  \
# 0        58    management      married   tertiary             no  2143.0
# 1        44    technician       single  secondary             no    29.0
# 2        33  entrepreneur      married  secondary             no     2.0
# 3        47   blue-collar      married    unknown             no  1506.0
# 4        33       unknown       single    unknown             no     1.0
# ...     ...           ...          ...        ...            ...     ...
# 45210    51    technician      married   tertiary             no   825.0
# 45211    71       retired     divorced    primary             no  1729.0
# 45212    72       retired      married  secondary             no  5715.0
# 45213    57   blue-collar      married  secondary             no   668.0
# 45214    37  entrepreneur      married  secondary             no  2971.0
#
#       vivienda prestamo   contacto  dia  mes  duracion  campaña  dias_previos  \
# 0          yes       no    unknown    5  may     261.0        1          -1.0
# 1          yes       no    unknown    5  may     151.0        1          -1.0
# 2          yes      yes    unknown    5  may      76.0        1          -1.0
# 3          yes       no    unknown    5  may      92.0        1          -1.0
# 4           no       no    unknown    5  may     198.0        1          -1.0
# ...        ...      ...        ...  ...  ...       ...      ...           ...
# 45210       no       no   cellular   17  nov     977.0        3          -1.0
# 45211       no       no   cellular   17  nov     456.0        2          -1.0
# 45212       no       no   cellular   17  nov    1127.0        5         184.0
# 45213       no       no  telephone   17  nov     508.0        4          -1.0
# 45214       no       no   cellular   17  nov     361.0        2         188.0
#
#        anterior resultado_prev respuesta
# 0             0        unknown        no
# 1             0        unknown        no
# 2             0        unknown        no
# 3             0        unknown        no
# 4             0        unknown        no
# ...         ...            ...       ...
# 45210         0        unknown       yes
# 45211         0        unknown       yes
# 45212         3        success       yes
# 45213         0        unknown        no
# 45214        11          other        no
#
# [45207 rows x 17 columns]

# %%
# Mostrar la cantidad de valores faltantes por columna
print(data.isnull().sum())
# Out:
# edad              0
# trabajo           0
# estado_civil      0
# educacion         0
# incumplimiento    0
# saldo             0
# vivienda          0
# prestamo          0
# contacto          0
# dia               0
# mes               0
# duracion          0
# campaña           0
# dias_previos      0
# anterior          0
# resultado_prev    0
# respuesta         0
# dtype: int64

# %%
# prompt:

# Eliminar las columnas que tengan más de 3000 valores nulos
data.dropna(thresh=3000, axis=1, inplace=True)

# Eliminar las filas que tengan al menos un valor nulo
data.dropna(how='any', axis=0, inplace=True)

# Verificar la cantidad de valores nulos restantes
print(data.isnull().sum())

# %%
# Realizamos lectura del archivo
data.tail()
print(data)
# Out:
#        edad       trabajo estado_civil  educacion incumplimiento   saldo  \
# 0        58    management      married   tertiary             no  2143.0
# 1        44    technician       single  secondary             no    29.0
# 2        33  entrepreneur      married  secondary             no     2.0
# 3        47   blue-collar      married    unknown             no  1506.0
# 4        33       unknown       single    unknown             no     1.0
# ...     ...           ...          ...        ...            ...     ...
# 45210    51    technician      married   tertiary             no   825.0
# 45211    71       retired     divorced    primary             no  1729.0
# 45212    72       retired      married  secondary             no  5715.0
# 45213    57   blue-collar      married  secondary             no   668.0
# 45214    37  entrepreneur      married  secondary             no  2971.0
#
#       vivienda prestamo   contacto  dia  mes  duracion  campaña  dias_previos  \
# 0          yes       no    unknown    5  may     261.0        1          -1.0
# 1          yes       no    unknown    5  may     151.0        1          -1.0
# 2          yes      yes    unknown    5  may      76.0        1          -1.0
# 3          yes       no    unknown    5  may      92.0        1          -1.0
# 4           no       no    unknown    5  may     198.0        1          -1.0
# ...        ...      ...        ...  ...  ...       ...      ...           ...
# 45210       no       no   cellular   17  nov     977.0        3          -1.0
# 45211       no       no   cellular   17  nov     456.0        2          -1.0
# 45212       no       no   cellular   17  nov    1127.0        5         184.0
# 45213       no       no  telephone   17  nov     508.0        4          -1.0
# 45214       no       no   cellular   17  nov     361.0        2         188.0
#
#        anterior resultado_prev respuesta
# 0             0        unknown        no
# 1             0        unknown        no
# 2             0        unknown        no
# 3             0        unknown        no
# 4             0        unknown        no
# ...         ...            ...       ...
# 45210         0        unknown       yes
# 45211         0        unknown       yes
# 45212         3        success       yes
# 45213         0        unknown        no
# 45214        11          other        no
#
# [45207 rows x 17 columns]

# %%
data.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45210   cellular   17   nov     977.0         3   -1.0         0  unknown  yes
# 45211   cellular   17   nov     456.0         2   -1.0         0  unknown  yes
# 45212   cellular   17   nov    1127.0         5  184.0         3  success  yes
# 45213  telephone   17   nov     508.0         4   -1.0         0  unknown   no
# 45214   cellular   17   nov     361.0         2  188.0        11    other   no

# %%
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no   2143.0     yes   no
# 1   44    technician   single  secondary      no     29.0     yes   no
# 2   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3   47   blue-collar  married    unknown      no   1506.0     yes   no
# 4   33       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may     261.0         1   -1.0         0  unknown  no
# 1  unknown    5   may     151.0         1   -1.0         0  unknown  no
# 2  unknown    5   may      76.0         1   -1.0         0  unknown  no
# 3  unknown    5   may      92.0         1   -1.0         0  unknown  no
# 4  unknown    5   may     198.0         1   -1.0         0  unknown  no

# %%
data.describe()
# Out:
#                edad          saldo           dia      duracion       campaña  \
# count  45207.000000   45207.000000  45207.000000  45207.000000  45207.000000
# mean      41.005596    1374.201318     15.806534    258.032539      2.763731
# std       12.037399    3924.491665      8.323015    257.460759      3.098058
# min       18.000000   -8019.000000      1.000000  -1389.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1427.500000     21.000000    319.000000      3.000000
# max      776.000000  527532.000000     31.000000   4918.000000     63.000000
#
#        dias_previos      anterior
# count  45207.000000  45207.000000
# mean      40.178225      0.580198
# std      100.103283      2.303341
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
data.query("educacion =='primary' and edad > 200")
# Out:
#       edad      trabajo estado_civil educacion incumplimiento   saldo  \
# 1076   490     services       single   primary             no   114.0
# 6053   399  blue-collar      married   primary             no  2805.0
#
#      vivienda prestamo contacto  dia  mes  duracion  campaña  dias_previos  \
# 1076      yes       no  unknown    7  may      99.0        2          -1.0
# 6053      yes       no  unknown   26  may     102.0       23          -1.0
#
#       anterior resultado_prev respuesta
# 1076         0        unknown        no
# 6053         0        unknown        no

# %%
print(data.shape)
# Out:
# (45207, 17)

# %%
data_rename_2 = data

# %%
df = data_rename_2

# %%
#cambia los nombres de las columnas del dataframe de Ingles a Español
# Renombramos las columnas
data_rename_2 = df.rename(columns={
                                  'age':        'edad',
                                  'job':        'trabajo',
                                  'marital':    'estado_civil',
                                  'education':  'educacion',
                                  'default':    'morosidad',
                                  'balance':    'saldo',
                                  'housing':    'vivienda',
                                  'loan':       'prestamo',
                                  'contact':    'contacto',
                                  'day':        'dia',
                                  'month':      'mes',
                                  'duration':   'duracion',
                                  'campaign':   'campana',
                                  'pdays':      'dias_previos',
                                  'previous':   'anterior',
                                  'poutcome':   'resultado',
                                  'y':          'respuesta'})

# Verificamos los cambios con el comando print
print(data_rename_2.head())
# Out:
#    edad       trabajo estado_civil  educacion incumplimiento   saldo vivienda  \
# 0    58    management      married   tertiary             no  2143.0      yes
# 1    44    technician       single  secondary             no    29.0      yes
# 2    33  entrepreneur      married  secondary             no     2.0      yes
# 3    47   blue-collar      married    unknown             no  1506.0      yes
# 4    33       unknown       single    unknown             no     1.0       no
#
#   prestamo contacto  dia  mes  duracion  campaña  dias_previos  anterior  \
# 0       no  unknown    5  may     261.0        1          -1.0         0
# 1       no  unknown    5  may     151.0        1          -1.0         0
# 2      yes  unknown    5  may      76.0        1          -1.0         0
# 3       no  unknown    5  may      92.0        1          -1.0         0
# 4       no  unknown    5  may     198.0        1          -1.0         0
#
#   resultado_prev respuesta
# 0        unknown        no
# 1        unknown        no
# 2        unknown        no
# 3        unknown        no
# 4        unknown        no

# %%
# Renombrar las columnas #2
df.columns = ['edad',
              'trabajo',
              'estado_civil',
              'educacion',
              'incumplimiento',
              'saldo',
              'vivienda',
              'prestamo',
              'contacto',
              'dia',
              'mes',
              'duracion',
              'campaña',
              'dias_previos',
              'anterior',
              'resultado_prev',
              'respuesta']

print(df.columns)
# Out:
# Index(['edad', 'trabajo', 'estado_civil', 'educacion', 'incumplimiento',
#        'saldo', 'vivienda', 'prestamo', 'contacto', 'dia', 'mes', 'duracion',
#        'campaña', 'dias_previos', 'anterior', 'resultado_prev', 'respuesta'],
#       dtype='object')

# %%
#visualiza las primeras líneas de tu .csv
df.head()
# Out:
#    edad       trabajo estado_civil  educacion incumplimiento   saldo vivienda  \
# 0    58    management      married   tertiary             no  2143.0      yes
# 1    44    technician       single  secondary             no    29.0      yes
# 2    33  entrepreneur      married  secondary             no     2.0      yes
# 3    47   blue-collar      married    unknown             no  1506.0      yes
# 4    33       unknown       single    unknown             no     1.0       no
#
#   prestamo contacto  dia  mes  duracion  campaña  dias_previos  anterior  \
# 0       no  unknown    5  may     261.0        1          -1.0         0
# 1       no  unknown    5  may     151.0        1          -1.0         0
# 2      yes  unknown    5  may      76.0        1          -1.0         0
# 3       no  unknown    5  may      92.0        1          -1.0         0
# 4       no  unknown    5  may     198.0        1          -1.0         0
#
#   resultado_prev respuesta
# 0        unknown        no
# 1        unknown        no
# 2        unknown        no
# 3        unknown        no
# 4        unknown        no

# %%
#visualiza las variables categóricas y las numéricas
# Clasificar columnas
categoricas = df.select_dtypes(include=['object']).columns.tolist()
numericas = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Columnas categóricas:", categoricas)
print("Columnas numéricas:", numericas)
# Out:
# Columnas categóricas: ['trabajo', 'estado_civil', 'educacion', 'incumplimiento', 'vivienda', 'prestamo', 'contacto', 'mes', 'resultado_prev', 'respuesta']
# Columnas numéricas: ['edad', 'saldo', 'dia', 'duracion', 'campaña', 'dias_previos', 'anterior']

# %%
pd.value_counts(df['trabajo'])
# Out:
# trabajo
# blue-collar       9730
# management        9454
# technician        7597
# admin.            5166
# services          4153
# retired           2263
# self-employed     1578
# entrepreneur      1487
# unemployed        1303
# housemaid         1240
# student            938
# unknown            288
# administrative       3
# Management           2
# MANAGEMENT           2
# Self-employed        1
# Services             1
# Retired              1
# Name: count, dtype: int64

# %%
#Comando para contar los valores faltantes de mi dataframe
data.isna().sum()
# Out:
# edad              0
# trabajo           0
# estado_civil      0
# educacion         0
# incumplimiento    0
# saldo             0
# vivienda          0
# prestamo          0
# contacto          0
# dia               0
# mes               0
# duracion          0
# campaña           0
# dias_previos      0
# anterior          0
# resultado_prev    0
# respuesta         0
# dtype: int64

# %%
#elimino los valores faltantes de mi dataframe
data.dropna(inplace=True)

#conteo de valores por columna de mi dataframe
data.count()
# Out:
# edad              45207
# trabajo           45207
# estado_civil      45207
# educacion         45207
# incumplimiento    45207
# saldo             45207
# vivienda          45207
# prestamo          45207
# contacto          45207
# dia               45207
# mes               45207
# duracion          45207
# campaña           45207
# dias_previos      45207
# anterior          45207
# resultado_prev    45207
# respuesta         45207
# dtype: int64

# %%
# Conteo de los niveles en las diferentes columnas categóricas
cols_cat = ['trabajo', 'estado_civil', 'educacion', 'incumplimiento', 'vivienda',
       'prestamo', 'contacto', 'mes', 'resultado_prev', 'respuesta']

for col in cols_cat:
  print(f'Columna {col}: {df[col].nunique()} subniveles')
# Out:
# Columna trabajo: 18 subniveles
# Columna estado_civil: 6 subniveles
# Columna educacion: 10 subniveles
# Columna incumplimiento: 2 subniveles
# Columna vivienda: 2 subniveles
# Columna prestamo: 6 subniveles
# Columna contacto: 5 subniveles
# Columna mes: 12 subniveles
# Columna resultado_prev: 6 subniveles
# Columna respuesta: 2 subniveles

# %%
#Conteo los valores
pd.value_counts(df['educacion'])
# Out:
# educacion
# secondary    23192
# tertiary     13301
# primary       6848
# unknown       1855
# SECONDARY        3
# Primary          2
# sec.             2
# UNK              2
# Secondary        1
# Tertiary         1
# Name: count, dtype: int64

# %%
# Calcular la desviación estándar para las columnas numéricas
desviaciones_estandar = data[['edad', 'saldo', 'dia', 'duracion', 'campaña', 'dias_previos', 'anterior']].std()

# Imprimir las desviaciones estándar
print(desviaciones_estandar)
# Out:
# edad              12.037399
# saldo           3924.491665
# dia                8.323015
# duracion         257.460759
# campaña            3.098058
# dias_previos     100.103283
# anterior           2.303341
# dtype: float64

# %%
#desviacion estandar para la variable 'pdays'
destd_pdays = data[['dias_previos']].std()

# Imprimir las desviaciones estándar
print(destd_pdays)
# Out:
# dias_previos    100.103283
# dtype: float64

# %%
# Crear una gráfica de barras para representar las desviaciones estándar
desviaciones_estandar.plot(kind='bar')
plt.title('Desviación Estándar de las Variables Numéricas')
plt.xlabel('Variables')
plt.ylabel('Desviación Estándar')
plt.xticks(rotation=45)
plt.show()

# %%
# Graficar la desviación estándar de 'pdays'
plt.figure(figsize=(4, 2))  # Configura el tamaño de la figura
plt.bar('dias_previos', destd_pdays)  # Crea una barra para la desviación estándar de 'pdays'
plt.title('Desviación Estándar de dias_previos')
plt.ylabel('Desviación Estándar')
plt.show()

# %%
# Calcula la media del atributo "pdays: dias de contacto al usuario antes de la campaña actual"
media = data['dias_previos'].mean()

print("Promedio de dias de contacto:", media)
# Out:
# Promedio de dias de contacto: 40.17822461123277

# %%
# Graficar un histograma del atributo "dias_previos"
plt.hist(data['dias_previos'], bins=20, color='skyblue', edgecolor='black')

# Agregar una línea vertical para mostrar la media
plt.axvline(media, color='red', linestyle='dashed', linewidth=1)

# Etiquetas y título
plt.xlabel('Valor de la pdays')
plt.ylabel('Frecuencia')
plt.title('Histograma de la pdays con Media')

# Mostrar la gráfica
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45207 entries, 0 to 45214
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   edad            45207 non-null  int64
#  1   trabajo         45207 non-null  object
#  2   estado_civil    45207 non-null  object
#  3   educacion       45207 non-null  object
#  4   incumplimiento  45207 non-null  object
#  5   saldo           45207 non-null  float64
#  6   vivienda        45207 non-null  object
#  7   prestamo        45207 non-null  object
#  8   contacto        45207 non-null  object
#  9   dia             45207 non-null  int64
#  10  mes             45207 non-null  object
#  11  duracion        45207 non-null  float64
#  12  campaña         45207 non-null  int64
#  13  dias_previos    45207 non-null  float64
#  14  anterior        45207 non-null  int64
#  15  resultado_prev  45207 non-null  object
#  16  respuesta       45207 non-null  object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 6.2+ MB

# %%
df['edad']
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45210    51
# 45211    71
# 45212    72
# 45213    57
# 45214    37
# Name: edad, Length: 45207, dtype: int64

# %%
df['contacto'].unique()
# Out:
# array(['unknown', 'cellular', 'telephone', 'phone', 'mobile'],
#       dtype=object)

# %%
df['saldo'].value_counts()
# Out:
# saldo
#  0.0        3514
#  1.0         195
#  2.0         156
#  4.0         139
#  3.0         134
#             ...
# -554.0         1
#  1792.0        1
# -381.0         1
#  4617.0        1
#  16353.0       1
# Name: count, Length: 7168, dtype: int64

# %%
df[df['edad'] > 15]
# Out:
#        edad       trabajo estado_civil  educacion incumplimiento   saldo  \
# 0        58    management      married   tertiary             no  2143.0
# 1        44    technician       single  secondary             no    29.0
# 2        33  entrepreneur      married  secondary             no     2.0
# 3        47   blue-collar      married    unknown             no  1506.0
# 4        33       unknown       single    unknown             no     1.0
# ...     ...           ...          ...        ...            ...     ...
# 45210    51    technician      married   tertiary             no   825.0
# 45211    71       retired     divorced    primary             no  1729.0
# 45212    72       retired      married  secondary             no  5715.0
# 45213    57   blue-collar      married  secondary             no   668.0
# 45214    37  entrepreneur      married  secondary             no  2971.0
#
#       vivienda prestamo   contacto  dia  mes  duracion  campaña  dias_previos  \
# 0          yes       no    unknown    5  may     261.0        1          -1.0
# 1          yes       no    unknown    5  may     151.0        1          -1.0
# 2          yes      yes    unknown    5  may      76.0        1          -1.0
# 3          yes       no    unknown    5  may      92.0        1          -1.0
# 4           no       no    unknown    5  may     198.0        1          -1.0
# ...        ...      ...        ...  ...  ...       ...      ...           ...
# 45210       no       no   cellular   17  nov     977.0        3          -1.0
# 45211       no       no   cellular   17  nov     456.0        2          -1.0
# 45212       no       no   cellular   17  nov    1127.0        5         184.0
# 45213       no       no  telephone   17  nov     508.0        4          -1.0
# 45214       no       no   cellular   17  nov     361.0        2         188.0
#
#        anterior resultado_prev respuesta
# 0             0        unknown        no
# 1             0        unknown        no
# 2             0        unknown        no
# 3             0        unknown        no
# 4             0        unknown        no
# ...         ...            ...       ...
# 45210         0        unknown       yes
# 45211         0        unknown       yes
# 45212         3        success       yes
# 45213         0        unknown        no
# 45214        11          other        no
#
# [45207 rows x 17 columns]

# %%
df[(df['edad'] == 47) & (df['dia'] == 5)]
# Out:
#        edad        trabajo estado_civil  educacion incumplimiento   saldo  \
# 3        47    blue-collar      married    unknown             no  1506.0
# 57       47    blue-collar      married    unknown             no   306.0
# 81       47       services     divorced  secondary             no   164.0
# 106      47     technician      married   tertiary             no   151.0
# 162      47       services       single  secondary             no   176.0
# 200      47         admin.      married  secondary             no   219.0
# 216      47        unknown      married    unknown             no    28.0
# 230      47    blue-collar      married    primary             no   -12.0
# 286      47         admin.      married  secondary             no   368.0
# 327      47     technician      married   tertiary             no   831.0
# 8990     47   entrepreneur     divorced   tertiary             no     0.0
# 9046     47   entrepreneur      married  secondary             no     0.0
# 9048     47     unemployed      married    primary             no  2946.0
# 9066     47    blue-collar      married    primary             no   421.0
# 9075     47     technician      married  secondary             no    89.0
# 9108     47     management      married   tertiary             no     0.0
# 9124     47    blue-collar      married    primary            yes     0.0
# 9145     47    blue-collar      married  secondary             no  1996.0
# 9291     47    blue-collar      married    unknown             no  3460.0
# 9304     47         admin.      married  secondary             no   407.0
# 9316     47     unemployed      married    primary             no   122.0
# 19067    47        unknown      married    unknown             no   301.0
# 19076    47     management      married   tertiary             no   295.0
# 19098    47         admin.      married  secondary             no   718.0
# 19122    47      housemaid      married    primary             no    32.0
# 19143    47         admin.      married  secondary             no     0.0
# 19153    47    blue-collar      married    primary             no   699.0
# 30218    47    blue-collar     divorced  secondary             no  1815.0
# 30267    47    blue-collar     divorced  secondary             no  -332.0
# 30293    47      housemaid     divorced  secondary             no  1565.0
# 30312    47     unemployed       single    primary             no   289.0
# 30356    47    blue-collar     divorced    primary             no  1927.0
# 30406    47     unemployed     divorced  secondary             no   947.0
# 30427    47     technician       single  secondary             no    58.0
# 30458    47         admin.       single   tertiary             no   178.0
# 30559    47  self-employed      married  secondary            yes     2.0
# 34430    47     management       single  secondary             no  -246.0
# 34462    47  self-employed      married    primary             no  3363.0
# 34509    47       services       single  secondary             no    33.0
# 34583    47     technician      married  secondary             no   232.0
# 34585    47    blue-collar      married    primary             no  -301.0
# 34599    47     management      married   tertiary             no  1649.0
# 34625    47     technician      married  secondary             no    57.0
# 34641    47         admin.      married  secondary             no   769.0
# 34709    47     technician      married    primary             no   434.0
# 34720    47   entrepreneur      married   tertiary             no     0.0
# 40631    47     management      married   tertiary             no   699.0
# 40645    47     management       single   tertiary             no    86.0
# 40651    47      housemaid      married  secondary             no  3940.0
# 43403    47         admin.      married  secondary             no    70.0
#
#       vivienda prestamo   contacto  dia  mes  duracion  campaña  dias_previos  \
# 3          yes       no    unknown    5  may      92.0        1          -1.0
# 57         yes       no    unknown    5  may      13.0        1          -1.0
# 81          no       No    unknown    5  may     212.0        1          -1.0
# 106        yes       no    unknown    5  may     190.0        1          -1.0
# 162        yes       no    unknown    5  may     303.0        2          -1.0
# 200        yes       no    unknown    5  may     577.0        1          -1.0
# 216         no       no    unknown    5  may     338.0        2          -1.0
# 230        yes       no    unknown    5  may      18.0        1          -1.0
# 286        yes       no    unknown    5  may     125.0        2          -1.0
# 327        yes       no    unknown    5  may     316.0        3          -1.0
# 8990        no       no    unknown    5  jun     124.0        1          -1.0
# 9046        no       no    unknown    5  jun    1446.0        1          -1.0
# 9048        no       no    unknown    5  jun      60.0        1          -1.0
# 9066       yes      yes    unknown    5  jun      52.0        1          -1.0
# 9075        no       no    unknown    5  jun     287.0        1          -1.0
# 9108        no       no    unknown    5  jun     265.0        2          -1.0
# 9124        no       no    unknown    5  jun     148.0        2          -1.0
# 9145        no       no    unknown    5  jun     761.0        2          -1.0
# 9291       yes       no    unknown    5  jun     394.0        2          -1.0
# 9304       yes       no    unknown    5  jun      67.0       12          -1.0
# 9316        no      yes    unknown    5  jun     240.0        3          -1.0
# 19067       no       no   cellular    5  aug     111.0        1          -1.0
# 19076      yes       no   cellular    5  aug     157.0        1          -1.0
# 19098      yes      yes   cellular    5  aug     195.0        2          -1.0
# 19122       no       no   cellular    5  aug     231.0        2          -1.0
# 19143       no       no   cellular    5  aug     109.0        4          -1.0
# 19153       no       no   cellular    5  aug     203.0        1          -1.0
# 30218      yes       no   cellular    5  feb     105.0        1         253.0
# 30267       no      yes   cellular    5  feb      48.0        2          -1.0
# 30293       no       no   cellular    5  feb     253.0        1          -1.0
# 30312       no       no   cellular    5  feb     210.0        1          -1.0
# 30356      yes       no   cellular    5  feb     130.0        4         275.0
# 30406       no       no   cellular    5  feb     124.0        2          -1.0
# 30427       no       no  telephone    5  feb      33.0        1          -1.0
# 30458       no       no  telephone    5  feb      17.0        6          -1.0
# 30559       no       no   cellular    5  feb     236.0        2          -1.0
# 34430      yes       no   cellular    5  may     145.0        1         365.0
# 34462       no       no   cellular    5  may     382.0        1          -1.0
# 34509      yes       no   cellular    5  may     298.0        1          -1.0
# 34583      yes       no   cellular    5  may     166.0        2         285.0
# 34585      yes       no   cellular    5  may     277.0        1          -1.0
# 34599      yes       no   cellular    5  may     217.0        2          -1.0
# 34625       no       no   cellular    5  may     253.0        1         342.0
# 34641      yes       no   cellular    5  may     183.0        1         265.0
# 34709      yes      yes   cellular    5  may     278.0        1          -1.0
# 34720       no       no   cellular    5  may     418.0        3          -1.0
# 40631       no       no   cellular    5  aug     432.0        3          97.0
# 40645       no       no   cellular    5  aug     253.0        1          97.0
# 40651      yes       no   cellular    5  aug     226.0        3          97.0
# 43403      yes       no   cellular    5  apr     144.0        4         374.0
#
#        anterior resultado_prev respuesta
# 3             0        unknown        no
# 57            0        unknown        no
# 81            0        unknown        no
# 106           0        unknown        no
# 162           0        unknown        no
# 200           0        unknown        no
# 216           0        unknown        no
# 230           0        unknown        no
# 286           0        unknown        no
# 327           0        unknown        no
# 8990          0        unknown        no
# 9046          0        unknown       yes
# 9048          0        unknown        no
# 9066          0        unknown        no
# 9075          0        unknown        no
# 9108          0        unknown        no
# 9124          0        unknown        no
# 9145          0        unknown       yes
# 9291          0        unknown        no
# 9304          0        unknown        no
# 9316          0        unknown        no
# 19067         0        unknown        no
# 19076         0        unknown        no
# 19098         0        unknown        no
# 19122         0        unknown        no
# 19143         0        unknown        no
# 19153         0        unknown        no
# 30218         4        failure        no
# 30267         0        unknown        no
# 30293         0        unknown        no
# 30312         0        unknown        no
# 30356         3        failure        no
# 30406         0        unknown        no
# 30427         0        unknown        no
# 30458         0        unknown        no
# 30559         0        unknown        no
# 34430         2        failure        no
# 34462         0        unknown        no
# 34509         0        unknown        no
# 34583         1        failure        no
# 34585         0        unknown        no
# 34599         0        unknown        no
# 34625         1        success        no
# 34641         2        failure        no
# 34709         0        unknown        no
# 34720         0        unknown        no
# 40631         2        success        no
# 40645         4        success       yes
# 40651         2        failure       yes
# 43403         2        success       yes

# %%
df.sort_values(by='edad', ascending=False)
# Out:
#        edad      trabajo estado_civil  educacion incumplimiento   saldo  \
# 43530   776      retired      married  secondary             no   820.0
# 229     530     services     divorced  secondary             no  1467.0
# 1076    490     services       single    primary             no   114.0
# 28152   466  blue-collar      married  secondary             no   120.0
# 6053    399  blue-collar      married    primary             no  2805.0
# ...     ...          ...          ...        ...            ...     ...
# 40747    18      student       single    unknown             no   108.0
# 41276    18      student       single    unknown             no     3.0
# 41225    18      student       single    unknown             no    35.0
# 42277    18      student       single    primary             no   608.0
# 44647    18      student       single    unknown             no   438.0
#
#       vivienda prestamo   contacto  dia  mes  duracion  campaña  dias_previos  \
# 43530       no       no  telephone   23  apr     263.0        4          -1.0
# 229        yes       no    unknown    5  may     124.0        1          -1.0
# 1076       yes       no    unknown    7  may      99.0        2          -1.0
# 28152      yes      yes   cellular   29  jan     121.0        1         259.0
# 6053       yes       no    unknown   26  may     102.0       23          -1.0
# ...        ...      ...        ...  ...  ...       ...      ...           ...
# 40747       no       no   cellular   10  aug     167.0        1          -1.0
# 41276       no       no   cellular   25  aug     130.0        2          -1.0
# 41225       no       no  telephone   21  aug     104.0        2          -1.0
# 42277       no       no   cellular   13  nov     210.0        1          93.0
# 44647       no       no   cellular    1  sep     425.0        1          -1.0
#
#        anterior resultado_prev respuesta
# 43530         0        unknown       yes
# 229           0        unknown        no
# 1076          0        unknown        no
# 28152         3        failure        no
# 6053          0        unknown        no
# ...         ...            ...       ...
# 40747         0        unknown       yes
# 41276         0        unknown       yes
# 41225         0        unknown        no
# 42277         1        success       yes
# 44647         0        unknown        no
#
# [45207 rows x 17 columns]
