# %% [markdown]
# <a href="https://colab.research.google.com/github/ccbeltran/Talento_Tech/blob/main/Trabajo_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Importar el archivo desde la ruta personal de Google Drive
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive')  # Establecemos la conexión através del método mount
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Establezco la conexión con mi fuente y con el dataset de prueba Dataset1.csv
ruta = '/content/drive/MyDrive/TalentoTech/Python/Base.csv'
df = pd.read_csv(ruta, nrows=20)
print(df)
# Out:
#     codigo_camara camara_comercio  matricula  inscripcion_proponente  \
# 0               1         ARMENIA       9249                       0
# 1               1         ARMENIA       9251                       0
# 2               1         ARMENIA       9253                       0
# 3               1         ARMENIA       9255                       0
# 4               1         ARMENIA       9257                       0
# 5              54    DOSQUEBRADAS      39592                       0
# 6               4          BOGOTA    2887840                       0
# 7               4          BOGOTA    2727102                       0
# 8               8            CALI    1150327                       0
# 9              23           HUILA     379204                       0
# 10              8            CALI     990092                       0
# 11              4          BOGOTA    1138528                       0
# 12              3    BARRANQUILLA     791579                       0
# ...
